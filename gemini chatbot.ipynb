# %%
# Importing Libraries
from langchain.utilities import SQLDatabase
from langchain.llms import OpenAI
from langchain.prompts import PromptTemplate
from langchain.chains import create_sql_query_chain
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_google_genai import ChatGoogleGenerativeAI
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Importing Libraries
# ----> 2 from langchain.utilities import SQLDatabase
#       3 from langchain.llms import OpenAI
#       4 from langchain.prompts import PromptTemplate
#
# ModuleNotFoundError: No module named 'langchain.utilities'

# %%
from langchain_community.utilities import SQLDatabase
from langchain_core.prompts import PromptTemplate
from langchain.chains import create_sql_query_chain
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_google_genai import ChatGoogleGenerativeAI
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_6408\2603511256.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.utilities import SQLDatabase
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 from langchain_community.utilities import SQLDatabase
#       2 from langchain_core.prompts import PromptTemplate
# ----> 3 from langchain.chains import create_sql_query_chain
#       4 from langchain_core.output_parsers import StrOutputParser
#       5 from langchain_core.runnables import RunnablePassthrough
#
# ModuleNotFoundError: No module named 'langchain.chains'

# %%
# %pip install -U langchain langchain-community langchain-core
# Out:
# Requirement already satisfied: langchain in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (1.4.2)
# Requirement already satisfied: langchain-community in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (0.4.2)
# Requirement already satisfied: langchain-core in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (1.6.3)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.11 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain) (1.2.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain) (2.13.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (3.14.3)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (0.13.0)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (2.4.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (2.15.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (2.34.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (2.0.49)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-core) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-core) (0.0.19)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-core) (26.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-core) (0.17.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.9.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.4)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.25.1)
# Requirement already satisfied: anyio in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (4.13.0)
# Requirement already satisfied: certifi in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (1.0.9)
# Requirement already satisfied: idna in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (3.20)
# Requirement already satisfied: h11>=0.16 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.1.1)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (0.4.4)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.0.1)
# Requirement already satisfied: distro>=1.7.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.9.0)
# Requirement already satisfied: httpx2<3,>=2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (2.13.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (16.1.1)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.2)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.4.0)
# Requirement already satisfied: greenlet>=1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.4.0)
# Requirement already satisfied: httpcore2==2.13.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.1.125->langchain-community) (2.13.0)
# Requirement already satisfied: truststore>=0.10 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.1.125->langchain-community) (0.10.4)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain) (1.12.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.utilities import SQLDatabase
from langchain_core.prompts import PromptTemplate
from langchain.chains import create_sql_query_chain
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_google_genai import ChatGoogleGenerativeAI
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_21616\2603511256.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.utilities import SQLDatabase
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 from langchain_community.utilities import SQLDatabase
#       2 from langchain_core.prompts import PromptTemplate
# ----> 3 from langchain.chains import create_sql_query_chain
#       4 from langchain_core.output_parsers import StrOutputParser
#       5 from langchain_core.runnables import RunnablePassthrough
#
# ModuleNotFoundError: No module named 'langchain.chains'

# %%
# %pip install -U langchain-classic
# Out:
# Requirement already satisfied: langchain-classic in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (1.0.8)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.4 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-classic) (1.6.3)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-classic) (1.1.2)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.17 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-classic) (0.13.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-classic) (2.13.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-classic) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-classic) (2.34.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-classic) (2.0.49)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.4.4->langchain-classic) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.4.4->langchain-classic) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.4.4->langchain-classic) (0.0.19)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.4.4->langchain-classic) (26.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.4.4->langchain-classic) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.4.4->langchain-classic) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.4.4->langchain-classic) (0.17.1)
# Requirement already satisfied: anyio>=3.5.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (4.13.0)
# Requirement already satisfied: distro>=1.7.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (1.9.0)
# Requirement already satisfied: httpx2<3,>=2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (2.13.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (16.1.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (2.46.2)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (3.20)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (2.4.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (2025.4.26)
# Requirement already satisfied: greenlet>=1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-classic) (3.4.0)
# Requirement already satisfied: httpcore==1.* in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.4->langchain-classic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.4->langchain-classic) (0.16.0)
# Requirement already satisfied: httpcore2==2.13.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.1.17->langchain-classic) (2.13.0)
# Requirement already satisfied: truststore>=0.10 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.1.17->langchain-classic) (0.10.4)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.4->langchain-classic) (3.1.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.utilities import SQLDatabase
from langchain_core.prompts import PromptTemplate
from langchain_classic.chains import create_sql_query_chain
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_google_genai import ChatGoogleGenerativeAI
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_11708\1201678217.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.utilities import SQLDatabase

# %%
# Connect MySQL database
host = 'localhost'
port = '3306'
username = 'root'
password = 'pasword'
database_schema = 'text_to_sql'

mysql_uri = f"mysql+pymysql://{username}:{password}@{host}:{port}/{database_schema}"

db = SQLDatabase.from_uri(mysql_uri, sample_rows_in_table_info=2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 10
#       6 database_schema = 'text_to_sql'
#       8 mysql_uri = f"mysql+pymysql://{username}:{password}@{host}:{port}/{database_schema}"
# ---> 10 db = SQLDatabase.from_uri(mysql_uri, sample_rows_in_table_info=2)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_community\utilities\sql_database.py:180, in SQLDatabase.from_uri(cls, database_uri, engine_args, **kwargs)
#     178 """Construct a SQLAlchemy engine from URI."""
#     179 _engine_args = engine_args or {}
# --> 180 return cls(create_engine(database_uri, **_engine_args), **kwargs)
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\util\deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\create.py:617, in create_engine(url, **kwargs)
#     615         if k in kwargs:
#     616             dbapi_args[k] = pop_kwarg(k)
# --> 617     dbapi = dbapi_meth(**dbapi_args)
#     619 dialect_args["dbapi"] = dbapi
#     621 dialect_args.setdefault("compiler_linting", compiler.NO_LINTING)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\dialects\mysql\pymysql.py:89, in MySQLDialect_pymysql.import_dbapi(cls)
#      87 @classmethod
#      88 def import_dbapi(cls) -> DBAPIModule:
# ---> 89     return __import__("pymysql")
#
# ModuleNotFoundError: No module named 'pymysql'

# %%
# %pip install pymysql
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting pymysql
#   Downloading pymysql-1.2.3-py3-none-any.whl (46 kB)
#                                               0.0/46.7 kB ? eta -:--:--
#      -----------------------------------      41.0/46.7 kB 2.0 MB/s eta 0:00:01
#      -------------------------------------- 46.7/46.7 kB 776.6 kB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.2.3
# [notice] A new release of pip is available: 23.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
host = 'localhost'
port = '3306'
username = 'root'
password = 'root'
database_schema = 'text_to_sql'

mysql_uri = f"mysql+pymysql://{username}:{password}@{host}:{port}/{database_schema}"

db = SQLDatabase.from_uri(mysql_uri, sample_rows_in_table_info=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       5 database_schema = 'text_to_sql'
#       7 mysql_uri = f"mysql+pymysql://{username}:{password}@{host}:{port}/{database_schema}"
# ----> 9 db = SQLDatabase.from_uri(mysql_uri, sample_rows_in_table_info=2)
#
# NameError: name 'SQLDatabase' is not defined

# %%
host = 'localhost'
port = '3306'
username = 'root'
password = 'password'
database_schema = 'text_to_sql'

mysql_uri = f"mysql+pymysql://{username}:{password}@{host}:{port}/{database_schema}"

db = SQLDatabase.from_uri(mysql_uri, sample_rows_in_table_info=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       5 database_schema = 'text_to_sql'
#       7 mysql_uri = f"mysql+pymysql://{username}:{password}@{host}:{port}/{database_schema}"
# ----> 9 db = SQLDatabase.from_uri(mysql_uri, sample_rows_in_table_info=2)
#
# NameError: name 'SQLDatabase' is not defined

# %%
from langchain_community.utilities import SQLDatabase
from langchain_core.prompts import PromptTemplate
from langchain_classic.chains import create_sql_query_chain
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_google_genai import ChatGoogleGenerativeAI
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_7688\1201678217.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.utilities import SQLDatabase

# %%
host = 'localhost'
port = '3306'
username = 'root'
password = 'password'
database_schema = 'text_to_sql'

mysql_uri = f"mysql+pymysql://{username}:{password}@{host}:{port}/{database_schema}"

db = SQLDatabase.from_uri(mysql_uri, sample_rows_in_table_info=2)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:681, in Connection.connect(self, sock)
#     680 try:
# --> 681     sock = socket.create_connection(
#     682         (self.host, self.port), self.connect_timeout, **kwargs
#     683     )
#     684     break
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\socket.py:827, in create_connection(address, timeout, source_address, all_errors)
#     826 exceptions = []
# --> 827 for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     828     af, socktype, proto, canonname, sa = res
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\socket.py:962, in getaddrinfo(host, port, family, type, proto, flags)
#     961 addrlist = []
# --> 962 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     963     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11003] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:3317, in Engine.raw_connection(self)
#    3296 """Return a "raw" DBAPI connection from the connection pool.
#    3297
#    3298 The returned object is a proxied version of the DBAPI
#    (...)
#    3315
#    3316 """
# -> 3317 return self.pool.connect()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
#     441 """Return a DBAPI connection from the pool.
#     442
#     443 The connection is instrumented such that when its
#    (...)
#     446
#     447 """
# --> 448 return _ConnectionFairy._checkout(self)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\pool\base.py:1272, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1271 if not fairy:
# -> 1272     fairy = _ConnectionRecord.checkout(pool)
#    1274     if threadconns is not None:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\pool\base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     176 except:
# --> 177     with util.safe_reraise():
#     178         self._dec_overflow()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\util\langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\pool\impl.py:175, in QueuePool._do_get(self)
#     174 try:
# --> 175     return self._create_connection()
#     176 except:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\pool\base.py:389, in Pool._create_connection(self)
#     387 """Called by subclasses to create a new ConnectionRecord."""
# --> 389 return _ConnectionRecord(self)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\pool\base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\pool\base.py:900, in _ConnectionRecord.__connect(self)
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\util\langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\pool\base.py:896, in _ConnectionRecord.__connect(self)
#     895 self.starttime = time.time()
# --> 896 self.dbapi_connection = connection = pool._invoke_creator(self)
#     897 pool.logger.debug("Created new connection %r", connection)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\create.py:667, in create_engine.<locals>.connect(connection_record)
#     666 else:
# --> 667     return dialect.connect(*cargs_tup, **cparams)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\default.py:630, in DefaultDialect.connect(self, *cargs, **cparams)
#     628 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     629     # inherits the docstring from interfaces.Dialect.connect
# --> 630     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:373, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_key_password, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     372 else:
# --> 373     self.connect()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:744, in Connection.connect(self, sock)
#     743         print(exc.traceback)
# --> 744     raise exc
#     746 # If e is neither DatabaseError or IOError, It's a bug.
#     747 # But raising AssertionError hides original error.
#     748 # So just reraise it.
#
# OperationalError: (2003, "Can't connect to MySQL server on '*@localhost' ([Errno 11003] getaddrinfo failed)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[4], line 9
#       5 database_schema = 'text_to_sql'
#       7 mysql_uri = f"mysql+pymysql://{username}:{password}@{host}:{port}/{database_schema}"
# ----> 9 db = SQLDatabase.from_uri(mysql_uri, sample_rows_in_table_info=2)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_community\utilities\sql_database.py:180, in SQLDatabase.from_uri(cls, database_uri, engine_args, **kwargs)
#     178 """Construct a SQLAlchemy engine from URI."""
#     179 _engine_args = engine_args or {}
# --> 180 return cls(create_engine(database_uri, **_engine_args), **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_community\utilities\sql_database.py:106, in SQLDatabase.__init__(self, engine, schema, metadata, ignore_tables, include_tables, sample_rows_in_table_info, indexes_in_table_info, custom_table_info, view_support, max_string_length, lazy_table_reflection)
#     103 if include_tables and ignore_tables:
#     104     raise ValueError("Cannot specify both include_tables and ignore_tables")
# --> 106 self._inspector = inspect(self._engine)
#     108 # including view support by adding the views as well as tables to the all
#     109 # tables list if view_support is True
#     110 self._all_tables = set(
#     111     list(self._inspector.get_table_names(schema=schema))
#     112     + (self._inspector.get_view_names(schema=schema) if view_support else [])
#    (...)
#     117     )
#     118 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\inspection.py:140, in inspect(subject, raiseerr)
#     138 elif reg is True:
#     139     return subject
# --> 140 ret = reg(subject)
#     141 if ret is not None:
#     142     return ret
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\reflection.py:313, in Inspector._engine_insp(bind)
#     311 @inspection._inspects(Engine)
#     312 def _engine_insp(bind: Engine) -> Inspector:  # type: ignore[misc]
# --> 313     return Inspector._construct(Inspector._init_engine, bind)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\reflection.py:246, in Inspector._construct(cls, init, bind)
#     243     cls = bind.dialect.inspector
#     245 self = cls.__new__(cls)
# --> 246 init(self, bind)
#     247 return self
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\reflection.py:257, in Inspector._init_engine(self, engine)
#     255 def _init_engine(self, engine: Engine) -> None:
#     256     self.bind = self.engine = engine
# --> 257     engine.connect().close()
#     258     self._op_context_requires_connect = True
#     259     self.dialect = self.engine.dialect
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:3293, in Engine.connect(self)
#    3270 def connect(self) -> Connection:
#    3271     """Return a new :class:`_engine.Connection` object.
#    3272
#    3273     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3290
#    3291     """
# -> 3293     return self._connection_cls(self)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143         self._dbapi_connection = engine.raw_connection()
#     144     except dialect.loaded_dbapi.Error as err:
# --> 145         Connection._handle_dbapi_exception_noconnection(
#     146             err, dialect, engine
#     147         )
#     148         raise
#     149 else:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:2448, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2446 elif should_wrap:
#    2447     assert sqlalchemy_exception is not None
# -> 2448     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2449 else:
#    2450     assert exc_info[1] is not None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     141 if connection is None:
#     142     try:
# --> 143         self._dbapi_connection = engine.raw_connection()
#     144     except dialect.loaded_dbapi.Error as err:
#     145         Connection._handle_dbapi_exception_noconnection(
#     146             err, dialect, engine
#     147         )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:3317, in Engine.raw_connection(self)
#    3295 def raw_connection(self) -> PoolProxiedConnection:
#    3296     """Return a "raw" DBAPI connection from the connection pool.
#    3297
#    3298     The returned object is a proxied version of the DBAPI
#    (...)
#    3315
#    3316     """
# -> 3317     return self.pool.connect()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
#     440 def connect(self) -> PoolProxiedConnection:
#     441     """Return a DBAPI connection from the pool.
#     442
#     443     The connection is instrumented such that when its
#    (...)
#     446
#     447     """
# --> 448     return _ConnectionFairy._checkout(self)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\pool\base.py:1272, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1264 @classmethod
#    1265 def _checkout(
#    1266     cls,
#    (...)
#    1269     fairy: Optional[_ConnectionFairy] = None,
#    1270 ) -> _ConnectionFairy:
#    1271     if not fairy:
# -> 1272         fairy = _ConnectionRecord.checkout(pool)
#    1274         if threadconns is not None:
#    1275             threadconns.current = weakref.ref(fairy)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\pool\base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     710     rec = cast(_ConnectionRecord, pool._do_get())
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#     715     dbapi_connection = rec.get_connection()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     175     return self._create_connection()
#     176 except:
# --> 177     with util.safe_reraise():
#     178         self._dec_overflow()
#     179     raise
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\util\langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     119     assert exc_value is not None
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#     123     self._exc_info = None  # remove potential circular references
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\pool\impl.py:175, in QueuePool._do_get(self)
#     173 if self._inc_overflow():
#     174     try:
# --> 175         return self._create_connection()
#     176     except:
#     177         with util.safe_reraise():
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\pool\base.py:389, in Pool._create_connection(self)
#     386 def _create_connection(self) -> ConnectionPoolEntry:
#     387     """Called by subclasses to create a new ConnectionRecord."""
# --> 389     return _ConnectionRecord(self)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\pool\base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     672 self.__pool = pool
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\pool\base.py:900, in _ConnectionRecord.__connect(self)
#     898     self.fresh = True
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#     902 else:
#     903     # in SQLAlchemy 1.4 the first_connect event is not used by
#     904     # the engine, so this will usually not be set
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\util\langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     119     assert exc_value is not None
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#     123     self._exc_info = None  # remove potential circular references
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\pool\base.py:896, in _ConnectionRecord.__connect(self)
#     894 try:
#     895     self.starttime = time.time()
# --> 896     self.dbapi_connection = connection = pool._invoke_creator(self)
#     897     pool.logger.debug("Created new connection %r", connection)
#     898     self.fresh = True
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\create.py:667, in create_engine.<locals>.connect(connection_record)
#     665     return dialect.connect(*mutable_cargs, **mutable_cparams)
#     666 else:
# --> 667     return dialect.connect(*cargs_tup, **cparams)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\default.py:630, in DefaultDialect.connect(self, *cargs, **cparams)
#     628 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     629     # inherits the docstring from interfaces.Dialect.connect
# --> 630     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:373, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_key_password, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     371     self._sock = None
#     372 else:
# --> 373     self.connect()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:744, in Connection.connect(self, sock)
#     742     if DEBUG:
#     743         print(exc.traceback)
# --> 744     raise exc
#     746 # If e is neither DatabaseError or IOError, It's a bug.
#     747 # But raising AssertionError hides original error.
#     748 # So just reraise it.
#     749 raise
#
# OperationalError: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '*@localhost' ([Errno 11003] getaddrinfo failed)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
from urllib.parse import quote_plus

# %%
host = 'localhost'
port = '3306'
username = 'root'
password = 'password'
database_schema = 'text_to_sql'

password_encoded = quote_plus(password)

mysql_uri = f"mysql+pymysql://{username}:{password_encoded}@{host}:{port}/{database_schema}"

db = SQLDatabase.from_uri(mysql_uri, sample_rows_in_table_info=2)

# %%
db = SQLDatabase.from_uri(mysql_uri, sample_rows_in_table_info=1)

db.get_table_info()
# Out:
# '\nCREATE TABLE `2017_budgets` (\n\t`Product Name` TEXT, \n\t`2017 Budgets` DOUBLE\n)COLLATE utf8mb4_0900_ai_ci ENGINE=InnoDB DEFAULT CHARSET=utf8mb4\n\n/*\n1 rows from 2017_budgets table:\nProduct Name\t2017 Budgets\nProduct 1\t3016489.2089999998\n*/\n\n\nCREATE TABLE customers (\n\t`Customer Index` INTEGER, \n\t`Customer Names` TEXT\n)COLLATE utf8mb4_0900_ai_ci ENGINE=InnoDB DEFAULT CHARSET=utf8mb4\n\n/*\n1 rows from customers table:\nCustomer Index\tCustomer Names\n1\tGeiss Company\n*/\n\n\nCREATE TABLE products (\n\t`Index` INTEGER, \n\t`Product Name` TEXT\n)COLLATE utf8mb4_0900_ai_ci ENGINE=InnoDB DEFAULT CHARSET=utf8mb4\n\n/*\n1 rows from products table:\nIndex\tProduct Name\n1\tProduct 1\n*/\n\n\nCREATE TABLE regions (\n\tid INTEGER, \n\tname TEXT, \n\tcounty TEXT, \n\tstate_code TEXT, \n\tstate TEXT, \n\ttype TEXT, \n\tlatitude DOUBLE, \n\tlongitude DOUBLE, \n\tarea_code INTEGER, \n\tpopulation INTEGER, \n\thouseholds INTEGER, \n\tmedian_income INTEGER, \n\tland_area INTEGER, \n\twater_area INTEGER, \n\ttime_zone TEXT\n)COLLATE utf8mb4_0900_ai_ci ENGINE=InnoDB DEFAULT CHARSET=utf8mb4\n\n/*\n1 rows from regions table:\nid\tname\tcounty\tstate_code\tstate\ttype\tlatitude\tlongitude\tarea_code\tpopulation\thouseholds\tmedian_income\tland_area\twater_area\ttime_zone\n1\tAuburn\tLee County\tAL\tAlabama\tCity\t32.6098600000\t-85.4807800000\t334\t62059\t21767\t38342\t152375113\t2646161\tAmerica/Chicago\n*/\n\n\nCREATE TABLE sales_order (\n\t`OrderNumber` TEXT, \n\t`OrderDate` TEXT, \n\t`Customer Name Index` INTEGER, \n\t`Channel` TEXT, \n\t`Currency Code` TEXT, \n\t`Warehouse Code` TEXT, \n\t`Delivery Region Index` INTEGER, \n\t`Product Description Index` INTEGER, \n\t`Order Quantity` INTEGER, \n\t`Unit Price` DOUBLE, \n\t`Line Total` DOUBLE, \n\t`Total Unit Cost` DOUBLE\n)COLLATE utf8mb4_0900_ai_ci ENGINE=InnoDB DEFAULT CHARSET=utf8mb4\n\n/*\n1 rows from sales_order table:\nOrderNumber\tOrderDate\tCustomer Name Index\tChannel\tCurrency Code\tWarehouse Code\tDelivery Region Index\tProduct Description Index\tOrder Quantity\tUnit Price\tLine Total\tTotal Unit Cost\nSO - 000225\t2021-01-01\t126\tWholesale\tUSD\tAXW291\t364\t27\t6\t2499.1000000000\t14994.6000000000\t1824.3430000000\n*/\n\n\nCREATE TABLE state_regions (\n\t`State Code` TEXT, \n\t`State` TEXT, \n\t`Region` TEXT\n)COLLATE utf8mb4_0900_ai_ci ENGINE=InnoDB DEFAULT CHARSET=utf8mb4\n\n/*\n1 rows from state_regions table:\nState Code\tState\tRegion\nAL\tAlabama\tSouth\n*/'

# %%
# Create the LLM Prompt Template
from langchain_core.prompts import ChatPromptTemplate

template = """Based on the table schema below, write a SQL query that would answer the user's question:
Remember : Only provide the sql query dont include anything else. Provide me sql query in a single line dont add line breaks
Table Schema: {schema}
Question: {question}
SQL Query:
"""

prompt = ChatPromptTemplate.from_template(template)

# %%
# get the schema of the database
def get_schema(db):
    schema = db.get_table_info()
    return schema

# %%
llm = ChatGoogleGenerativeAI(
    model = 'gemini-2.0-flash',
    api_key = ''
)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 llm = ChatGoogleGenerativeAI(
#       2     model = 'gemini-2.0-flash',
#       3     api_key = ''
#       4 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_google_genai\chat_models.py:3308, in ChatGoogleGenerativeAI.__init__(self, **kwargs)
#    3301         suggestion = (
#    3302             f" Did you mean: '{suggestions[0]}'?" if suggestions else ""
#    3303         )
#    3304         logger.warning(
#    3305             f"Unexpected argument '{arg}' "
#    3306             f"provided to ChatGoogleGenerativeAI.{suggestion}"
#    3307         )
# -> 3308 super().__init__(**kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\load\serializable.py:136, in Serializable.__init__(self, *args, **kwargs)
#     134 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     135     """"""  # noqa: D419  # Intentional blank docstring
# --> 136     super().__init__(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pydantic\main.py:263, in BaseModel.__init__(self, **data)
#     261 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     262 __tracebackhide__ = True
# --> 263 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     264 if self is not validated_self:
#     265     warnings.warn(
#     266         'A custom validator is returning a value other than `self`.\n'
#     267         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     268         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     269         stacklevel=2,
#     270     )
#
# ValidationError: 1 validation error for ChatGoogleGenerativeAI
#   Value error, API key required for Gemini Developer API. Provide api_key parameter or set GOOGLE_API_KEY/GEMINI_API_KEY environment variable. [type=value_error, input_value={'model': 'gemini-2.0-fla...e, 'google_api_key': ''}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/value_error

# %%
llm = ChatGoogleGenerativeAI(
    model='gemini-2.0-flash',
    api_key='xyz'
)

# %%
sql_chain = (
    RunnablePassthrough.assign(schema=lambda _: get_schema(db))
    | prompt
    | llm.bind(stop=["\nSQLResult:"])
    | StrOutputParser()
)

# %%
resp = sql_chain.invoke({"question": "What is the total 'Line Total' for Geiss Company"})
print(resp)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_google_genai\chat_models.py:4177, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    4176 try:
# -> 4177     response: GenerateContentResponse = self.client.models.generate_content(
#    4178         **request,
#    4179     )
#    4180 except ClientError as e:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\genai\models.py:6270, in Models.generate_content(self, model, contents, config)
#    6269 i += 1
# -> 6270 response = self._generate_content(
#    6271     model=model, contents=contents, config=parsed_config_to_call
#    6272 )
#    6274 if not function_map:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\genai\models.py:4707, in Models._generate_content(self, model, contents, config)
#    4705 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4707 response = self._api_client.request(
#    4708     'post', path, request_dict, http_options
#    4709 )
#    4711 if config is not None and getattr(
#    4712     config, 'should_return_http_response', None
#    4713 ):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\genai\_api_client.py:1750, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1747 http_request = self._build_request(
#    1748     http_method, path, request_dict, http_options
#    1749 )
# -> 1750 response = self._request(http_request, http_options, stream=False)
#    1751 response_body = (
#    1752     response.response_stream[0] if response.response_stream else ''
#    1753 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\genai\_api_client.py:1535, in BaseApiClient._request(self, http_request, http_options, stream)
#    1534     retry = tenacity.Retrying(**retry_kwargs)
# -> 1535     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1537 return self._retry(self._request_once, http_request, stream)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tenacity\__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     392 if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393     self._add_action_func(lambda rs: rs.outcome.result())
#     394     return
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     472 try:
# --> 473     result = fn(*args, **kwargs)
#     474 except BaseException:  # noqa: B902
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\genai\_api_client.py:1514, in BaseApiClient._request_once(self, http_request, stream)
#    1513   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr, arg-type]
# -> 1514 errors.APIError.raise_for_response(response)
#    1515 return HttpResponse(
#    1516     response.headers, response if stream else [response.text]
#    1517 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\genai\errors.py:173, in APIError.raise_for_response(cls, response)
#     171   response_json = response.body_segments[0].get('error', {})
# --> 173 cls.raise_error(response.status_code, response_json, response)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\genai\errors.py:202, in APIError.raise_error(cls, status_code, response_json, response)
#     201 if 400 <= status_code < 500:
# --> 202   raise ClientError(status_code, response_json, response)
#     203 elif 500 <= status_code < 600:
#
# ClientError: 404 NOT_FOUND. {'error': {'code': 404, 'message': 'This model models/gemini-2.0-flash is no longer available. Please update your code to use models/gemini-3.6-flash for the latest features and improvements. We recommend you to use the Interactions API.', 'status': 'NOT_FOUND'}}
#
# The above exception was the direct cause of the following exception:
#
# GoogleModelNotFoundError                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 resp = sql_chain.invoke({"question": "What is the total 'Line Total' for Geiss Company"})
#       2 print(resp)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\runnables\base.py:3456, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3454                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3455             else:
# -> 3456                 input_ = context.run(step.invoke, input_, config)
#    3457 # finish the root run
#    3458 except BaseException as e:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\runnables\base.py:6014, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    6007 @override
#    6008 def invoke(
#    6009     self,
#    (...)
#    6012     **kwargs: Any | None,
#    6013 ) -> Output:
# -> 6014     return self.bound.invoke(
#    6015         input,
#    6016         self._merge_configs(config),
#    6017         **{**self.kwargs, **kwargs},
#    6018     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_google_genai\chat_models.py:3578, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    3575         msg = "Tools are already defined.code_execution tool can't be defined"
#    3576         raise ValueError(msg)
# -> 3578 return super().invoke(input, config, stop=stop, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\language_models\chat_models.py:488, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     474 @override
#     475 def invoke(
#     476     self,
#    (...)
#     481     **kwargs: Any,
#     482 ) -> AIMessage:
#     483     config = ensure_config(config)
#     484     return cast(
#     485         "AIMessage",
#     486         cast(
#     487             "ChatGeneration",
# --> 488             self.generate_prompt(
#     489                 [self._convert_input(input)],
#     490                 stop=stop,
#     491                 callbacks=config.get("callbacks"),
#     492                 tags=config.get("tags"),
#     493                 metadata=config.get("metadata"),
#     494                 run_name=config.get("run_name"),
#     495                 run_id=config.pop("run_id", None),
#     496                 **kwargs,
#     497             ).generations[0][0],
#     498         ).message,
#     499     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\language_models\chat_models.py:1877, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1868 @override
#    1869 def generate_prompt(
#    1870     self,
#    (...)
#    1874     **kwargs: Any,
#    1875 ) -> LLMResult:
#    1876     prompt_messages = [p.to_messages() for p in prompts]
# -> 1877     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\language_models\chat_models.py:1684, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1681 for i, m in enumerate(input_messages):
#    1682     try:
#    1683         results.append(
# -> 1684             self._generate_with_cache(
#    1685                 m,
#    1686                 stop=stop,
#    1687                 run_manager=run_managers[i] if run_managers else None,
#    1688                 **kwargs,
#    1689             )
#    1690         )
#    1691     except BaseException as e:
#    1692         if run_managers:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\language_models\chat_models.py:2022, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    2020     result = generate_from_stream(iter(chunks))
#    2021 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 2022     result = self._generate(
#    2023         messages, stop=stop, run_manager=run_manager, **kwargs
#    2024     )
#    2025 else:
#    2026     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_google_genai\chat_models.py:4181, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    4177     response: GenerateContentResponse = self.client.models.generate_content(
#    4178         **request,
#    4179     )
#    4180 except ClientError as e:
# -> 4181     _handle_client_error(e, request)
#    4182 except ServerError as e:
#    4183     _handle_server_error(e)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_google_genai\chat_models.py:326, in _handle_client_error(e, request)
#     324 msg = f"Error calling model '{model_name}' ({e.status}): {e}"
#     325 if error_type := _CLIENT_ERROR_TYPES.get(e.code):
# --> 326     raise error_type(msg) from e
#     327 raise ChatGoogleGenerativeAIError(msg) from e
#
# GoogleModelNotFoundError: Error calling model 'gemini-2.0-flash' (NOT_FOUND): 404 NOT_FOUND. {'error': {'code': 404, 'message': 'This model models/gemini-2.0-flash is no longer available. Please update your code to use models/gemini-3.6-flash for the latest features and improvements. We recommend you to use the Interactions API.', 'status': 'NOT_FOUND'}}

# %%
llm = ChatGoogleGenerativeAI(
    model='gemini-3.6-flash',
    api_key='xyz'
)

# %%
sql_chain = (
    RunnablePassthrough.assign(schema=lambda _: get_schema(db))
    | prompt
    | llm.bind(stop=["\nSQLResult:"])
    | StrOutputParser()
)

# %%
resp = sql_chain.invoke({"question": "What is the total 'Line Total' for Geiss Company"})
print(resp)
# Out:
# SELECT SUM(t1.`Line Total`) FROM sales_order AS t1 JOIN customers AS t2 ON t1.`Customer Name Index` = t2.`Customer Index` WHERE t2.`Customer Names` = 'Geiss Company'

# %%
import os

print("Folder:")
print(os.getcwd())

print("\nNotebooks in this folder:")
print([f for f in os.listdir() if f.endswith(".ipynb")])
# Out:
# Folder:
# C:\Users\dell
#
# Notebooks in this folder:
# ['gemini chatbot rag.ipynb', 'gemini chatbot.ipynb']
